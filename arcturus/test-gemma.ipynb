# %%
import os
from dotenv import load_dotenv
from google import genai

# Search for .env file in current and parent directories
env_found = False
for path in ['.env', '../.env', '../../.env']:
    if os.path.exists(path):
        load_dotenv(path)
        env_found = True
        print(f"Loaded .env from: {os.path.abspath(path)}")
        break

if not env_found:
    print("Warning: .env file not found!")

model_id = 'gemma-4-26b-a4b-it'
# Out:
# Loaded .env from: d:\Reza Fauzan\Skunk Works 2\Palatine\Palatine 2.0\.env

# %% [markdown]
# ### LIVE ANSWER CODE
#
# To get the model to print its output live (like a typing effect) instead of waiting for the entire response to finish, you need to enable streaming.
#
# If you want to see the model's "thoughts" (its internal reasoning process) before it gives the final answer, you will also need to point it to a specific "Thinking" model.

# %%
import os
from dotenv import load_dotenv
from google import genai
import sys

# 1. Setup
api_key = os.getenv("GEMMA_API_KEY")
if not api_key:
    raise ValueError("GEMMA_API_KEY not found in environment variables. Check your .env file.")

client = genai.Client(api_key=api_key)
model_id = 'gemma-4-26b-a4b-it'

print(f"Using model: {model_id}")
print("Sending request to Google's servers...\n")
print("--- Live Output Begins ---")

# 2. Generate content with streaming
try:
    response = client.models.generate_content_stream(
        model=model_id,
        contents="How does a PID controller adjust motor speed? Walk me through the math.", 
    )

    # 3. Iterate through the chunks as they arrive from the server
    for chunk in response:
        if chunk.text:
            print(chunk.text, end="", flush=True)
except Exception as e:
    print(f"\nError during API request: {e}")

print("\n\n--- Output Complete ---")
# Out:
# Using model: gemma-4-26b-a4b-it
# Sending request to Google's servers...
#
# --- Live Output Begins ---
# To understand how a PID controller adjusts motor speed, you have to view it as a **feedback loop**. The controller's job is to minimize the "Error"—the difference between how fast you *want* the motor to spin (the Setpoint) and how fast it is *actually* spinning (the Process Variable).
#
# Here is the step-by-step breakdown of the logic and the math.
#
# ---
#
# ### 1. The Foundation: The Error
# Before any math happens, the controller calculates the error ($e$) at a specific moment in time ($t$).
#
# $$e(t) = \text{Setpoint} - \text{Measured Speed}$$
#
# If you want the motor to spin at $1000 \text{ RPM}$ and it is currently spinning at $800 \text{ RPM}$, your error is $200$.
#
# ---
#
# ### 2. The Three Components
# The PID controller calculates three separate mathematical terms and adds them together to decide how much voltage (or PWM signal) to send to the motor.
#
# #### A. Proportional (P): "The Present"
# The Proportional term is the most intuitive. It applies an output that is directly proportional to the current error. If the error is large, the push is large. If the error is small, the push is small.
#
# **The Math:**
# $$P_{out} = K_p \cdot e(t)$$
#
# *   $K_p$ is the "Proportional Gain" (a tuning constant).
# *   **The Problem:** If you rely *only* on P, the motor will never actually reach the setpoint. As the error gets smaller, the output gets smaller. Eventually, the output becomes too weak to overcome friction, and the motor settles at a speed slightly below the target. This is called **Steady-State Error**.
#
# #### B. Integral (I): "The Past"
# The Integral term looks at the history of the error. It asks: *"How long have we been away from the target?"* It sums up (integrates) the error over time. If the error persists, the integral term grows larger and larger, eventually forcing the motor to close that final gap.
#
# **The Math:**
# $$I_{out} = K_i \cdot \int_{0}^{t} e(\tau) \, d\tau$$
#
# *   $K_i$ is the "Integral Gain."
# *   **The Problem:** If $K_i$ is too high, the controller "over-accumulates" error. By the time the motor reaches the setpoint, the Integral term is so huge that the motor flies right past it. This is called **Overshoot**.
#
# #### C. Derivative (D): "The Future"
# The Derivative term looks at the *rate of change* of the error. It acts as a brake. It asks: *"How fast are we approaching the target?"* If the error is shrinking very rapidly, the derivative term becomes a negative value, slowing down the motor to prevent it from overshooting.
#
# **The Math:**
# $$D_{out} = K_d \cdot \frac{de(t)}{dt}$$
#
# *   $K_d$ is the "Derivative Gain."
# *   **The Problem:** The derivative is extremely sensitive to "noise." If your speed sensor has tiny, jittery fluctuations, the derivative term will see those as massive "changes" and cause the motor to vibrate or chatter.
#
# ---
#
# ### 3. The Complete Equation
# The controller combines these three to produce the total Control Output ($u(t)$), which is usually sent to the motor driver as a PWM signal.
#
# $$u(t) = \underbrace{K_p e(t)}_{\text{Proportional}} + \underbrace{K_i \int_{0}^{t} e(\tau) \, d\tau}_{\text{Integral}} + \underbrace{K_d \frac{de(t)}{dt}}_{\text{Derivative}}$$
#
# ---
#
# ### 4. A Practical Walkthrough (Discrete Math)
# In the real world, a microcontroller (like an Arduino) doesn't do calculus; it does **discrete math** using small time steps ($\Delta t$). Here is how the math actually looks inside the code:
#
# **Scenario:**
# *   Target: $1000 \text{ RPM}$
# *   Current: $800 \text{ RPM}$ (Error = $200$)
# *   Assume $K_p=0.5, K_i=0.1, K_d=0.05$ and $\Delta t=0.1\text{s}$.
#
# **Step 1: Proportional Calculation**
# $$P = 0.5 \times 200 = 100$$
#
# **Step 2: Integral Calculation (Summing up error)**
# The computer keeps a running total of error. Let's say the previous error sum was $1500$.
# $$\text{New Sum} = 1500 + (200 \times 0.1) = 1520$$
# $$I = 0.1 \times 1520 = 152$$
#
# **Step 3: Derivative Calculation (Difference in error)**
# Let's say last time the error was $210$. The error changed by $-10$.
# $$\text{Rate of change} = \frac{-10}{0.1} = -100$$
# $$D = 0.05 \times -100 = -5$$
#
# **Step 4: Total Output**
# $$u(t) = 100 + 152 - 5 = 247$$
# The controller sends a signal of **247** to the motor.
#
# ### Summary Table
# | Term | Function | Analogy | Problem if too high |
# | :--- | :--- | :--- | :--- |
# | **Proportional** | Corrects current error | The Muscle | Steady-state error (never quite arrives) |
# | **Integral** | Corrects accumulated error | The Persistence | Overshoot (flies past the target) |
# | **Derivative** | Predicts future error | The Brake | Instability/Jitter (reacts to noise) |
#
# --- Output Complete ---

# %%
import os
from dotenv import load_dotenv
from google import genai
from google.genai import types

load_dotenv()
api_key = os.getenv("GEMMA_API_KEY")
if not api_key:
    raise ValueError("GEMMA_API_KEY not found in environment variables.")

client = genai.Client(api_key=api_key)
model_id = "gemma-4-26b-a4b-it"
print(f"Using model: {model_id}")
print("Sending request...\n")

thoughts = ""
answer = ""

try:
    for chunk in client.models.generate_content_stream(
        model=model_id,
        contents="How does a PID controller adjust motor speed? Walk me through the math.",
        config=types.GenerateContentConfig(
            thinking_config=types.ThinkingConfig(thinking_level="high")  # FIX 1: use ThinkingConfig
        ),
    ):
        for part in chunk.candidates[0].content.parts:  # FIX 2: iterate parts, check part.thought
            if not part.text:
                continue
            if part.thought:
                if not thoughts:
                    print("=" * 40)
                    print("[THINKING PROCESS]")
                    print("=" * 40)
                print(part.text, end="", flush=True)
                thoughts += part.text
            else:
                if not answer:
                    print("\n\n" + "=" * 40)
                    print("[ACTUAL RESPONSE]")
                    print("=" * 40)
                print(part.text, end="", flush=True)
                answer += part.text

except Exception as e:
    print(f"\nError: {e}")

print("\n\n--- Output Complete ---")
# Out:
# Using model: gemma-4-26b-a4b-it
# Sending request...
#
# ========================================
# [THINKING PROCESS]
# ========================================
# PID (Proportional-Integral-Derivative) controller.
# Motor speed adjustment.
# Walk through the math.
#
#     *   What is it? A feedback loop mechanism.
#     *   What are the components?
#         *   $P$ (Proportional): Current error.
#         *   $I$ (Integral): Accumulated past error.
#         *   $D$ (Derivative): Predicted future error (rate of change).
#     *   Key Variables:
#         *   $SP$ (Set Point): Desired speed.
#         *   $PV$ (Process Variable): Actual speed.
#         *   $e(t)$ (Error): $SP - PV$.
#         *   $u(t)$ (Control Output): Voltage/PWM sent to the motor.
#
#     A good technical explanation should follow a logical progression:
#     *   **Introduction:** Define the goal (maintaining speed) and the context (feedback loop).
#     *   **The Setup:** Define the variables.
#     *   **The Core Logic (The Error):** The foundation of all PID math.
#     *   **Component Breakdown:**
#         *   Proportional (The "Now").
#         *   Integral (The "Past").
#         *   Derivative (The "Future").
#     *   **The Combined Equation:** Putting it all together.
#     *   **A Concrete Example:** Walking through a numerical scenario.
#     *   **Summary Table/Analogy.**
#
#         *   Input: $u(t)$ (e.g., PWM duty cycle or Voltage).
#         *   Output: $y(t)$ (Motor speed).
#         *   Desired: $r(t)$ (Set point).
#         *   Measured: $y(t)$ (Current speed).
#         *   Error: $e(t) = r(t) - y(t)$.
#
#         *   *Proportional:* $K_p \cdot e(t)$.
#             *   *Concept:* Big error $\to$ big correction. Small error $\to$ small correction.
#             *   *Problem:* Steady-state error (it never quite reaches the goal because if error is 0, output is 0).
#
#         *   *Integral:* $K_i \cdot \int e(t) \, dt$.
#             *   *Concept:* Accumulate error over time. If error persists, the integral grows, pushing the motor harder.
#             *   *Solution:* Fixes the steady-state error.
#             *   *Problem:* Overshoot/Windup.
#
#         *   *Derivative:* $K_d \cdot \frac{de(t)}{dt}$.
#             *   *Concept:* Look at the slope. If error is decreasing rapidly, slow down the correction to prevent overshoot.
#             *   *Solution:* Damping/Stability.
#
#         *   $u(t) = K_p e(t) + K_i \int_{0}^{t} e(\tau) \, d\tau + K_d \frac{de(t)}{dt}$
#
#         *   *Scenario:* Desired speed = 1000 RPM. Current speed = 800 RPM.
#         *   *Constants:* $K_p = 0.5, K_i = 0.1, K_d = 0.05$.
#         *   *Step 1 (P):* $e = 200$. $P = 0.5 \cdot 200 = 100$.
#         *   *Step 2 (I):* Assume it's been 2 seconds at this error. $I = 0.1 \cdot (200 \cdot 2) = 40$.
#         *   *Step 3 (D):* Assume error is dropping fast (slope = -50). $D = 0.05 \cdot (-50) = -2.5$.
#         *   *Total:* $100 + 40 - 2.5 = 137.5$ (Voltage/PWM units).
#
#     *   Use LaTeX for math symbols.
#     *   Use bolding for emphasis.
#     *   Check for clarity: Did I explain *why* each part exists? (Yes, by mentioning the flaws of the others).
#     *   Check the "motor" aspect: Ensure I mention that $u(t)$ translates to Voltage or PWM.
#
# (This matches the provided good response.)
#
# ========================================
# [ACTUAL RESPONSE]
# ========================================
# To understand how a PID controller adjusts motor speed, you have to view it as a continuous mathematical correction loop. The goal is to minimize the difference between where you **want** the motor to be (Set Point) and where the motor **actually** is (Process Variable).
#
# Here is the step-by-step walkthrough of the logic and the math.
#
# ---
#
# ### 1. The Fundamental Variable: The Error
# Before we calculate the PID components, we must define the **Error**, denoted as $e(t)$.
#
# If your desired speed (Set Point, $SP$) is 1000 RPM, and your motor is currently spinning at 800 RPM (Process Variable, $PV$), your error is:
# $$e(t) = SP - PV$$
# $$e(t) = 1000 - 800 = 200$$
#
# The PID controller’s job is to calculate a control signal $u(t)$ (usually a Voltage or a PWM duty cycle) to drive this error to zero.
#
# ---
#
# ### 2. The Three Components
# The PID controller calculates three separate values based on the error and sums them together:
#
# #### A. Proportional (The "Present")
# The Proportional term is the simplest. It applies a correction that is directly proportional to the current error.
# $$\text{P-Term} = K_p \cdot e(t)$$
# *   **How it works:** If the error is large, the motor gets a lot of power. If the error is small, the motor gets a little power.
# *   **The Flaw:** If you only use P, the motor will often suffer from **Steady-State Error**. As the motor gets closer to the target speed, the error gets so small that the P-term no longer provides enough voltage to overcome friction, so the motor stops just short of the target.
#
# #### B. Integral (The "Past")
# The Integral term looks at the history of the error. It sums up (integrates) all past errors over time.
# $$\text{I-Term} = K_i \int_{0}^{t} e(\tau) \, d\tau$$
# *   **How it works:** If the motor is stuck at 950 RPM (50 RPM below target) and the error persists, the Integral term keeps growing and growing. Eventually, it becomes large enough to "force" the motor to bridge that final gap.
# *   **The Flaw:** If the $K_i$ is too high, the controller can "over-correct," causing the motor to overshoot the target and oscillate wildly.
#
# #### C. Derivative (The "Future")
# The Derivative term looks at the *rate of change* of the error. It calculates the slope of the error curve.
# $$\text{D-Term} = K_d \cdot \frac{de(t)}{dt}$$
# *   **How it works:** It acts as a brake. If the error is shrinking very rapidly (meaning the motor is accelerating toward the target too fast), the derivative becomes a negative number. This "subtracts" from the total power to prevent the motor from overshooting.
# *   **The Flaw:** It is very sensitive to "noise." If your speed sensor has tiny jitters, the derivative will see those as massive changes in speed and cause the motor to vibrate.
#
# ---
#
# ### 3. The Complete Equation
# The total control output $u(t)$ sent to the motor driver is the sum of these three terms:
#
# $$u(t) = \underbrace{K_p e(t)}_{\text{Proportional}} + \underbrace{K_i \int_{0}^{t} e(\tau) \, d\tau}_{\text{Integral}} + \underbrace{K_d \frac{de(t)}{dt}}_{\text{Derivative}}$$
#
# Where:
# *   $u(t)$ = The output (e.g., Voltage or PWM).
# *   $K_p, K_i, K_d$ = The "tuning gains" (constants you set).
#
# ---
#
# ### 4. A Numerical Example
# Let's imagine we are tuning a motor.
# *   **Target ($SP$):** 1000 RPM
# *   **Current ($PV$):** 800 RPM
# *   **Error ($e$):** 200 RPM
# *   **Gains:** $K_p = 0.5$, $K_i = 0.1$, $K_d = 0.05$
#
# **Step 1: Calculate P**
# $$P = 0.5 \times 200 = 100$$
#
# **Step 2: Calculate I**
# Assume the motor has been stuck at 800 RPM for 2 seconds.
# $$I = 0.1 \times (200 \times 2 \text{ seconds}) = 40$$
#
# **Step 3: Calculate D**
# Assume the motor is speeding up, and the error is dropping at a rate of 50 RPM per second. (The derivative of error is $-50$).
# $$D = 0.05 \times (-50) = -2.5$$
#
# **Step 4: Final Output**
# $$u(t) = 100 + 40 - 2.5 = 137.5$$
#
# The controller sends a signal of **137.5 units** to the motor to drive it toward the target.
#
# ---
#
# ### Summary Table
# | Term | Logic | Primary Purpose | Potential Problem |
# | :--- | :--- | :--- | :--- |
# | **Proportional** | "The error is big, push hard." | Speed of response | Never reaches target (Steady-state error) |
# | **Integral** | "The error has lasted too long." | Eliminates steady-state error | Overshoot and oscillation |
# | **Derivative** | "We are approaching fast, slow down." | Stability and damping | Sensitivity to sensor noise |
#
# --- Output Complete ---
