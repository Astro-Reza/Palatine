# %%
import os
from dotenv import load_dotenv
from google import genai

# Search for .env file in current and parent directories
env_found = False
for path in ['.env', '../.env', '../../.env']:
    if os.path.exists(path):
        load_dotenv(path)
        env_found = True
        print(f"Loaded .env from: {os.path.abspath(path)}")
        break

if not env_found:
    print("Warning: .env file not found!")

model_id = 'gemma-4-26b-a4b-it'
# Out:
# Loaded .env from: d:\Reza Fauzan\Skunk Works 2\Palatine\Palatine 2.0\.env

# %% [markdown]
# ### LIVE ANSWER CODE
#
# To get the model to print its output live (like a typing effect) instead of waiting for the entire response to finish, you need to enable streaming.
#
# If you want to see the model's "thoughts" (its internal reasoning process) before it gives the final answer, you will also need to point it to a specific "Thinking" model.

# %%
import os
from dotenv import load_dotenv
from google import genai
import sys

# 1. Setup
api_key = os.getenv("GEMMA_API_KEY")
if not api_key:
    raise ValueError("GEMMA_API_KEY not found in environment variables. Check your .env file.")

client = genai.Client(api_key=api_key)
model_id = 'gemma-4-26b-a4b-it'

print(f"Using model: {model_id}")
print("Sending request to Google's servers...\n")
print("--- Live Output Begins ---")

# 2. Generate content with streaming
try:
    response = client.models.generate_content_stream(
        model=model_id,
        contents="How does a PID controller adjust motor speed? Walk me through the math.", 
    )

    # 3. Iterate through the chunks as they arrive from the server
    for chunk in response:
        if chunk.text:
            print(chunk.text, end="", flush=True)
except Exception as e:
    print(f"\nError during API request: {e}")

print("\n\n--- Output Complete ---")
# Out:
# Using model: gemma-4-26b-a4b-it
# Sending request to Google's servers...
#
# --- Live Output Begins ---
# To understand how a PID controller adjusts motor speed, you have to view it as a **feedback loop**. The controller's job is to minimize the "Error"—the difference between how fast you *want* the motor to spin (the Setpoint) and how fast it is *actually* spinning (the Process Variable).
#
# Here is the step-by-step breakdown of the logic and the math.
#
# ---
#
# ### 1. The Foundation: The Error
# Before any math happens, the controller calculates the error ($e$) at a specific moment in time ($t$).
#
# $$e(t) = \text{Setpoint} - \text{Measured Speed}$$
#
# If you want the motor to spin at $1000 \text{ RPM}$ and it is currently spinning at $800 \text{ RPM}$, your error is $200$.
#
# ---
#
# ### 2. The Three Components
# The PID controller calculates three separate mathematical terms and adds them together to decide how much voltage (or PWM signal) to send to the motor.
#
# #### A. Proportional (P): "The Present"
# The Proportional term is the most intuitive. It applies an output that is directly proportional to the current error. If the error is large, the push is large. If the error is small, the push is small.
#
# **The Math:**
# $$P_{out} = K_p \cdot e(t)$$
#
# *   $K_p$ is the "Proportional Gain" (a tuning constant).
# *   **The Problem:** If you rely *only* on P, the motor will never actually reach the setpoint. As the error gets smaller, the output gets smaller. Eventually, the output becomes too weak to overcome friction, and the motor settles at a speed slightly below the target. This is called **Steady-State Error**.
#
# #### B. Integral (I): "The Past"
# The Integral term looks at the history of the error. It asks: *"How long have we been away from the target?"* It sums up (integrates) the error over time. If the error persists, the integral term grows larger and larger, eventually forcing the motor to close that final gap.
#
# **The Math:**
# $$I_{out} = K_i \cdot \int_{0}^{t} e(\tau) \, d\tau$$
#
# *   $K_i$ is the "Integral Gain."
# *   **The Problem:** If $K_i$ is too high, the controller "over-accumulates" error. By the time the motor reaches the setpoint, the Integral term is so huge that the motor flies right past it. This is called **Overshoot**.
#
# #### C. Derivative (D): "The Future"
# The Derivative term looks at the *rate of change* of the error. It acts as a brake. It asks: *"How fast are we approaching the target?"* If the error is shrinking very rapidly, the derivative term becomes a negative value, slowing down the motor to prevent it from overshooting.
#
# **The Math:**
# $$D_{out} = K_d \cdot \frac{de(t)}{dt}$$
#
# *   $K_d$ is the "Derivative Gain."
# *   **The Problem:** The derivative is extremely sensitive to "noise." If your speed sensor has tiny, jittery fluctuations, the derivative term will see those as massive "changes" and cause the motor to vibrate or chatter.
#
# ---
#
# ### 3. The Complete Equation
# The controller combines these three to produce the total Control Output ($u(t)$), which is usually sent to the motor driver as a PWM signal.
#
# $$u(t) = \underbrace{K_p e(t)}_{\text{Proportional}} + \underbrace{K_i \int_{0}^{t} e(\tau) \, d\tau}_{\text{Integral}} + \underbrace{K_d \frac{de(t)}{dt}}_{\text{Derivative}}$$
#
# ---
#
# ### 4. A Practical Walkthrough (Discrete Math)
# In the real world, a microcontroller (like an Arduino) doesn't do calculus; it does **discrete math** using small time steps ($\Delta t$). Here is how the math actually looks inside the code:
#
# **Scenario:**
# *   Target: $1000 \text{ RPM}$
# *   Current: $800 \text{ RPM}$ (Error = $200$)
# *   Assume $K_p=0.5, K_i=0.1, K_d=0.05$ and $\Delta t=0.1\text{s}$.
#
# **Step 1: Proportional Calculation**
# $$P = 0.5 \times 200 = 100$$
#
# **Step 2: Integral Calculation (Summing up error)**
# The computer keeps a running total of error. Let's say the previous error sum was $1500$.
# $$\text{New Sum} = 1500 + (200 \times 0.1) = 1520$$
# $$I = 0.1 \times 1520 = 152$$
#
# **Step 3: Derivative Calculation (Difference in error)**
# Let's say last time the error was $210$. The error changed by $-10$.
# $$\text{Rate of change} = \frac{-10}{0.1} = -100$$
# $$D = 0.05 \times -100 = -5$$
#
# **Step 4: Total Output**
# $$u(t) = 100 + 152 - 5 = 247$$
# The controller sends a signal of **247** to the motor.
#
# ### Summary Table
# | Term | Function | Analogy | Problem if too high |
# | :--- | :--- | :--- | :--- |
# | **Proportional** | Corrects current error | The Muscle | Steady-state error (never quite arrives) |
# | **Integral** | Corrects accumulated error | The Persistence | Overshoot (flies past the target) |
# | **Derivative** | Predicts future error | The Brake | Instability/Jitter (reacts to noise) |
#
# --- Output Complete ---

# %%
import os
from dotenv import load_dotenv
from google import genai
from google.genai import types

load_dotenv()
api_key = os.getenv("GEMMA_API_KEY")
if not api_key:
    raise ValueError("GEMMA_API_KEY not found in environment variables.")

client = genai.Client(api_key=api_key)
model_id = "gemma-4-26b-a4b-it"
print(f"Using model: {model_id}")
print("Sending request...\n")

thoughts = ""
answer = ""

try:
    for chunk in client.models.generate_content_stream(
        model=model_id,
        contents="How does a PID controller adjust motor speed? Walk me through the math.",
        config=types.GenerateContentConfig(
            thinking_config=types.ThinkingConfig(thinking_level="high")  # FIX 1: use ThinkingConfig
        ),
    ):
        for part in chunk.candidates[0].content.parts:  # FIX 2: iterate parts, check part.thought
            if not part.text:
                continue
            if part.thought:
                if not thoughts:
                    print("=" * 40)
                    print("[THINKING PROCESS]")
                    print("=" * 40)
                print(part.text, end="", flush=True)
                thoughts += part.text
            else:
                if not answer:
                    print("\n\n" + "=" * 40)
                    print("[ACTUAL RESPONSE]")
                    print("=" * 40)
                print(part.text, end="", flush=True)
                answer += part.text

except Exception as e:
    print(f"\nError: {e}")

print("\n\n--- Output Complete ---")
# Out:
# Using model: gemma-4-26b-a4b-it
# Sending request...
#
# ========================================
# [THINKING PROCESS]
# ========================================
#
# *   Topic: PID controller adjusting motor speed.
#     *   Goal: Explain *how* it works and walk through the *math*.
#     *   Audience: Likely someone interested in engineering, robotics, or control theory (needs clarity but technical depth).
#
#     *   What is a PID controller? (Proportional, Integral, Derivative).
#     *   The goal: Control a process variable (motor speed) to match a setpoint.
#     *   The core concept: The "Error" ($e(t)$).
#
#     *   Input: Setpoint ($SP$) - the desired speed.
#     *   Output: Process Variable ($PV$) - the actual speed.
#     *   Error: $e(t) = SP - PV$.
#     *   Control Output: $u(t)$ (the signal sent to the motor driver, e.g., PWM duty cycle).
#
#     *   **P (Proportional): "The Present"**
#         *   Idea: Correct based on how far away we are right now.
#         *   Math: $P = K_p \cdot e(t)$.
#         *   Physical meaning: High error $\rightarrow$ high power. Low error $\rightarrow$ low power.
#         *   Limitation: Steady-state error (it can't reach the goal because as error goes to zero, power goes to zero).
#
#     *   **I (Integral): "The Past"**
#         *   Idea: Correct based on the accumulation of errors over time.
#         *   Math: $I = K_i \cdot \int_{0}^{t} e(\tau) \, d\tau$.
#         *   Physical meaning: If error persists, the "sum" builds up, forcing the motor to go faster.
#         *   Benefit: Eliminates steady-state error.
#         *   Limitation: Integral windup (over-correcting).
#
#     *   **D (Derivative): "The Future"**
#         *   Idea: Correct based on how fast the error is changing.
#         *   Math: $D = K_d \cdot \frac{de(t)}{dt}$.
#         *   Physical meaning: Acts as a brake/damper. If error is closing quickly, it slows down the correction to prevent overshoot.
#         *   Benefit: Reduces oscillation/overshoot.
#         *   Limitation: Sensitive to noise.
#
#     *   $u(t) = K_p e(t) + K_i \int_{0}^{t} e(\tau) \, d\tau + K_d \frac{de(t)}{dt}$
#
#     *   Scenario: Setpoint = 1000 RPM. Actual = 800 RPM.
#     *   Step 1: Calculate error ($e = 200$).
#     *   Step 2: Proportional term ($200 \times K_p$).
#     *   Step 3: Integral term (Accumulating $200$ every second).
#     *   Step 4: Derivative term (If speed is rising at $50$ RPM/sec, the derivative is negative).
#     *   Step 5: Summing them up to get the PWM signal.
#
#     *   Use LaTeX-style formatting for math.
#     *   Use analogies (e.g., driving a car).
#     *   Structure with clear headings.
#
#     *   *Initial thought:* Just give the formula.
#     *   *Correction:* No, the user asked "how it adjusts motor speed," so I need to explain the relationship between the control signal $u(t)$ and the motor (PWM).
#     *   *Addition:* Mentioning Discrete PID (since computers don't do calculus, they do summation/difference). This makes it practical.
#
# ========================================
# [ACTUAL RESPONSE]
# ========================================
# To understand how a PID (Proportional-Integral-Derivative) controller adjusts motor speed, you have to view it as a constant feedback loop. The controller's job is to minimize the **Error**, which is the difference between where you want the motor to be (Setpoint) and where it actually is (Measured Speed).
#
# Here is the walkthrough of the logic and the mathematics.
#
# ---
#
# ### 1. The Variables
# Before the math, we define our terms:
# *   $r(t)$: **Setpoint** (The desired speed, e.g., 1000 RPM).
# *   $y(t)$: **Process Variable** (The actual speed measured by an encoder).
# *   $e(t)$: **Error** ($r(t) - y(t)$).
# *   $u(t)$: **Control Signal** (The output sent to the motor, usually a PWM duty cycle).
# *   $K_p, K_i, K_d$: **Gains** (The "tuning knobs" that determine how hard each part of the controller works).
#
# ---
#
# ### 2. The Three Components of the Math
#
# A PID controller calculates the output $u(t)$ by summing three distinct mathematical operations.
#
# #### A. Proportional (The "Present")
# The Proportional term is simple: the further you are from the target, the harder you push.
#
# $$P = K_p \cdot e(t)$$
#
# *   **How it affects the motor:** If the error is large (motor is stopped but target is 1000 RPM), the $P$ term provides a massive burst of power. As the motor approaches 1000 RPM, the error shrinks, and the power decreases.
# *   **The Flaw:** Proportional control alone usually suffers from **Steady-State Error**. As the motor gets very close to the target, the error becomes so small that the power output isn't enough to overcome friction, so the motor stalls just below the target.
#
# #### B. Integral (The "Past")
# The Integral term looks at the history of the error. It sums up (integrates) all past errors over time.
#
# $$I = K_i \int_{0}^{t} e(\tau) \, d\tau$$
#
# *   **How it affects the motor:** If the motor is stuck at 980 RPM (just below the 1000 RPM target), the error is $20$. The Proportional term might be too weak to move it, but the Integral term sees that $20$ is being added to the "bucket" every millisecond. Eventually, the "bucket" gets heavy enough to force the motor to that final 1000 RPM.
# *   **The Flaw:** If $K_i$ is too high, the controller "over-learns," causing the motor to overshoot the target wildly (this is called **Integral Windup**).
#
# #### C. Derivative (The "Future")
# The Derivative term looks at the *rate of change* of the error. It predicts where the error is heading.
#
# $$D = K_d \frac{de(t)}{dt}$$
#
# *   **How it affects the motor:** If the motor is accelerating toward the target extremely fast, the derivative of the error becomes a large negative number. This acts as a **brake**. It senses the "momentum" of the error closing and reduces power *before* you hit the target, preventing overshoot.
# *   **The Flaw:** Derivative control is very sensitive to "noise." If your speed sensor has tiny, jittery fluctuations, the derivative will see those as massive changes and cause the motor to vibrate.
#
# ---
#
# ### 3. The Complete PID Equation
#
# When you combine them, the controller calculates the output signal $u(t)$ like this:
#
# $$u(t) = \underbrace{K_p e(t)}_{\text{Proportional}} + \underbrace{K_i \int_{0}^{t} e(\tau) d\tau}_{\text{Integral}} + \underbrace{K_d \frac{de(t)}{dt}}_{\text{Derivative}}$$
#
# ---
#
# ### 4. Real-World Implementation (Discrete Math)
# In a real micro-controller (like an Arduino), you cannot perform true calculus (integrals and derivatives). Instead, you use **Discrete PID**, which uses a small time step ($\Delta t$).
#
# The computer calculates the adjustment at every loop:
#
# 1.  **Error:** $e[n] = \text{Setpoint} - \text{CurrentSpeed}$
# 2.  **Proportional:** $P = K_p \cdot e[n]$
# 3.  **Integral:** $I = I_{\text{previous}} + (K_i \cdot e[n] \cdot \Delta t)$
# 4.  **Derivative:** $D = K_d \cdot \frac{e[n] - e[n-1]}{\Delta t}$
# 5.  **Output:** $u[n] = P + I + D$
#
# ---
#
# ### Summary Walkthrough: A Speed Increase Scenario
#
# Imagine you want a motor to go from **0 to 1000 RPM**.
#
# 1.  **At $t=0$:** Error is $1000$. $P$ is huge, $I$ is $0$, $D$ is $0$. The motor gets full power.
# 2.  **As speed hits 800:** Error is $200$. $P$ drops significantly. However, the $I$ term has been accumulating error during the climb, so it is now providing extra "oomph" to keep the speed rising.
# 3.  **As speed hits 950:** The speed is rising very fast. The $D$ term sees the error shrinking rapidly ($\frac{de}{dt}$ is negative) and subtracts power from the total output. This prevents the motor from slamming into 1100 RPM.
# 4.  **At 1000 RPM:** Error is $0$. $P$ is $0$, $D$ is $0$. The motor is held at exactly 1000 RPM by the $I$ term, which has "saved up" just enough power to counteract the motor's internal friction.
#
# --- Output Complete ---

# %% [markdown]
# # GEMMA 4 (26B) A4B IT
# IS NOT SUPPORTING THINKING LEVEL

# %%
import os
from dotenv import load_dotenv
from google import genai
from google.genai import types # REQUIRED: Import types for the config

# 1. Setup
load_dotenv() # Make sure to actually load the .env file!
api_key = os.getenv("GEMMA_API_KEY")

if not api_key:
    raise ValueError("GEMMA_API_KEY not found in environment variables. Check your .env file.")

client = genai.Client(api_key=api_key)
model_id = 'gemma-4-26b-a4b-it' 

print(f"Using model: {model_id}")
print("Sending request to Google's servers...\n")
print("--- Live Output Begins ---")

# 2. Generate content with streaming and adjustable thinking
try:
    response = client.models.generate_content_stream(
        model=model_id,
        contents="How does a PID controller adjust motor speed? Walk me through the math.",
        config=types.GenerateContentConfig(
            # This is where you adjust the thinking
            thinking_config=types.ThinkingConfig(
                thinking_level=types.ThinkingLevel.LOW, # Options: HIGH, MEDIUM, LOW, MINIMAL
                include_thoughts=True # Ensure thoughts are returned in the stream
            )
        )
    )

    # 3. Iterate through the chunks as they arrive from the server
    for chunk in response:
        if chunk.text:
            print(chunk.text, end="", flush=True)

except Exception as e:
    print(f"\nError during API request: {e}")

print("\n\n--- Output Complete ---")
# Out:
# Using model: gemma-4-26b-a4b-it
# Sending request to Google's servers...
#
# --- Live Output Begins ---
#
# Error during API request: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Thinking level is not supported for this model.', 'status': 'INVALID_ARGUMENT'}}
#
#
# --- Output Complete ---
