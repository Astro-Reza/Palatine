# %%
from google import genai

model='gemma-4-26b-a4b-it'

# %% [markdown]
# ### LIVE ANSWER CODE
#
# To get the model to print its output live (like a typing effect) instead of waiting for the entire response to finish, you need to enable streaming.
#
# If you want to see the model's "thoughts" (its internal reasoning process) before it gives the final answer, you will also need to point it to a specific "Thinking" model.

# %%
from google import genai
import sys

# 1. Setup
# Replace with your actual API key
api_key = "AIzaSyAazrqVx-UmY5QhJlANrLekvKYSuo6R8fM"
client = genai.Client(api_key=api_key)

model_id = 'gemma-4-26b-a4b-it'

print("Sending request to Google's servers...\n")
print("--- Live Output Begins ---")

# 2. Generate content with streaming
# The new SDK uses generate_content_stream for live typing effects
response = client.models.generate_content_stream(
    model=model_id,
    contents="How does a PID controller adjust motor speed? Walk me through the math.", 
)

# 3. Iterate through the chunks as they arrive from the server
for chunk in response:
    # Use chunk.text to get the generated content
    if chunk.text:
        print(chunk.text, end="", flush=True)

print("\n\n--- Output Complete ---")
# Out:
# Sending request to Google's servers...
#
# --- Live Output Begins ---
# To understand how a PID controller adjusts motor speed, you first have to understand the **Closed-Loop Feedback** concept.
#
# A PID controller doesn't just "set" a speed; it constantly asks, *"How far away am I from where I want to be, and how fast am I approaching it?"*
#
# ---
#
# ### 1. The Variables
# Before the math, we define our terms:
# *   **Setpoint ($SP$):** The target speed you want (e.g., 1000 RPM).
# *   **Process Variable ($PV$):** The actual current speed measured by a sensor (e.g., an encoder).
# *   **Error ($e(t)$):** The difference between the two.
#     $$e(t) = SP - PV$$
# *   **Output ($u(t)$):** The control signal sent to the motor (usually a PWM signal to adjust voltage).
#
# ---
#
# ### 2. The Three Components (The Math)
#
# The PID controller calculates the output by summing three distinct mathematical terms: **Proportional, Integral, and Derivative.**
#
# #### A. The Proportional Term ($P$) — *"The Present"*
# This is the simplest part. The controller applies an output proportional to the current error. If the error is large, the motor gets a lot of power. If the error is small, it gets a little power.
#
# **Math:**
# $$P = K_p \cdot e(t)$$
# *(Where $K_p$ is the proportional gain constant)*
#
# *   **Problem:** If you only use $P$, you will suffer from **Steady-State Error**. As the motor gets closer to the target speed, the error becomes so small that the power output isn't enough to overcome friction, so the motor stalls just below the target.
#
# #### B. The Integral Term ($I$) — *"The Past"*
# To fix the steady-state error, we look at the history of the error. The Integral term sums up (integrates) all past errors over time. Even if the current error is tiny, if it persists for a long time, the integral sum will grow larger and larger, eventually forcing the motor to reach the target.
#
# **Math:**
# $$I = K_i \int_{0}^{t} e(\tau) \,d\tau$$
# *(Where $K_i$ is the integral gain constant)*
#
# *   **Problem:** If $K_i$ is too high, the controller becomes "impatient." It accumulates so much error that it overshoots the target speed significantly.
#
# #### C. The Derivative Term ($D$) — *"The Future"*
# The Derivative term looks at the **rate of change** of the error. It calculates how fast the error is shrinking or growing. If the error is shrinking very rapidly (meaning we are approaching the target fast), the Derivative term produces a "braking" effect to slow down the approach and prevent overshoot.
#
# **Math:**
# $$D = K_d \frac{de(t)}{dt}$$
# *(Where $K_d$ is the derivative gain constant)*
#
# *   **Problem:** The Derivative term is very sensitive to "noise." If your sensor reading jitters slightly, the derivative (slope) will spike wildly, causing the motor to vibrate.
#
# ---
#
# ### 3. The Full PID Equation
#
# The controller combines these three to produce the final command to the motor:
#
# $$u(t) = \underbrace{K_p e(t)}_{\text{Proportional}} + \underbrace{K_i \int_{0}^{t} e(\tau) \,d\tau}_{\text{Integral}} + \underbrace{K_d \frac{de(t)}{dt}}_{\text{Derivative}}$$
#
# ---
#
# ### 4. A Practical Walkthrough (Example)
#
# Imagine you want a motor to spin at **1000 RPM**.
#
# **Scenario: The motor is currently spinning at 800 RPM.**
#
# 1.  **Error Calculation:**
#     $$e(t) = 1000 - 800 = 200 \text{ RPM}$$
#
# 2.  **Proportional Action:**
#     The controller sees a massive error of 200. It calculates $K_p \times 200$. If $K_p = 2$, the output is **400 units of power**. The motor kicks into high gear.
#
# 3.  **Integral Action:**
#     The motor is at 800, but it's stuck there due to friction. The error is 200.
#     *   After 1 second: Integral = $200 \times 1 = 200$
#     *   After 2 seconds: Integral = $200 \times 2 = 400$
#     The power output slowly climbs because the error is "piling up." This eventually pushes the motor past the friction threshold.
#
# 4.  **Derivative Action:**
#     As the motor accelerates from 800 toward 1000, the error is dropping rapidly (from 200 to 100 to 50).
#     The $\frac{de}{dt}$ (slope) becomes a **negative number**.
#     This negative value is subtracted from the total output, effectively "tapping the brakes" so the motor doesn't fly past 1000 RPM.
#
# ### Summary Table
#
# | Term | Analogy | Primary Job | Main Weakness |
# | :--- | :--- | :--- | :--- |
# | **P** | The Muscle | Corrects current error | Leaves a constant offset (Steady-state error) |
# | **I** | The Memory | Eliminates the offset | Causes overshoot and oscillation |
# | **D** | The Brake | Dampens the movement | Reacts badly to sensor noise |
#
# --- Output Complete ---
